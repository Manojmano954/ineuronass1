# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# hello
# -87.8
# -
# /
# +
# 6
# ANS:*,-,/,+ ------>MATHEMATICAL OPERATOR
#    hello ,-87.8,6 ---->STRING,FLOAT,INTEGER

# %% [markdown]
# 2. What is the difference between string and variable?
#
#   ANS:String is a datatype which is collection of alphabets,words etc
#      Ex: 'manoj',"mano123@"
#
#    VARIABLE: Variable is name assigning the data

# %% [markdown]
# 3. Describe three different data types
#
#
# ans: Integer :it is a whole number ,without decimals ,positive or negative
#
#                eg:1,2,22,55,5555,-4,-100 etc
#
#      String: it is collection of alphabets,words.
#
#            eg: "manoj","MANOJ!@#"
#
#     List:Collection of different datatypes of data.it is mutable.
#
#              eg:[1,2,"manoj",1.5]

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
#
# ans:  Expression is made up of combination of operand and operator
#
#      an expression will perform an operation and then assigned result to variable EXP: X=X+5

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
#
#  ans: Statement is assigining the values to variable and displaying the values. Eg:spam=10
#
#    expression is combination of operand and operator
#       eg: spam=spam+10

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
bacon=22
bacon+1
# Out:
# 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# spam + spamspam
# spam * 3
#
#  ANS: spam+spamspam is the string concatination and "spam *3" is 3 times spam can print one after another

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#  ans: python variable has some set of rules. variable that won't start with numericals and other special characters and predifed words in the python

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?
#
# Ans:  int(),float(),str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
#  "I have eaten"  + 99 + "burritos"
#
#  Ans: Here we are doing string concatination but 99 is the integer value it can't allow to concatinate

# %%
A="I have eaten"+"99"+"burritos"
print(A)
